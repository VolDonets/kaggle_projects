# %% [markdown]
# # Import the dependencies

# %%
import numpy as np
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt
from matplotlib import rcParams

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Some theory by ChatGPT:
#
# Here are the top 10 methods commonly used for solving regression problems in Python:
#
# 1. Linear Regression: Fits a linear model to the data by minimizing the sum of squared residuals.
# 2. Decision Tree Regression: Uses a decision tree to make predictions based on feature values.
# 3. Random Forest Regression: An ensemble method that combines multiple decision trees to make predictions.
# 4. Gradient Boosting Regression: Builds an ensemble of weak prediction models (usually decision trees) sequentially, where each model corrects the mistakes of the previous one.
# 5. Support Vector Regression: Uses support vector machines to perform regression by finding the optimal hyperplane that maximally fits the data.
# 6. Neural Network Regression: Utilizes artificial neural networks to learn and model complex relationships in the data.
# 7. K-Nearest Neighbors Regression: Makes predictions based on the average of the target values of the k nearest neighbors in the feature space.
# 8. Ridge Regression: Performs linear regression with a penalty term to prevent overfitting by shrinking the coefficients.
# 9. Lasso Regression: Performs linear regression with a penalty term that encourages sparsity by forcing some coefficients to be exactly zero.
# 10. Elastic Net Regression: Combines Ridge and Lasso regression techniques to provide a balance between the two.
#
# These methods offer different approaches and are suitable for various regression problem scenarios. It's important to understand their strengths and limitations and choose the most appropriate method based on your specific dataset, problem requirements, and computational considerations.

# %% [markdown]
# # Load data

# %%
data = pd.read_csv("src/train.csv")
data = data.drop("Id", axis=1)

data_test = pd.read_csv("src/test.csv")
data_test = data_test.drop("Id", axis=1)
data_test['SalePrice'] = pd.read_csv("src/sample_submission.csv")['SalePrice'].tolist()

# %%
data = data[[rec != "NoSeWa" for rec in data["Utilities"]]].reset_index(drop=True)
data = data[[rec != "RRNn" for rec in data["Condition2"]]].reset_index(drop=True)
data = data[[rec != "RRAn" for rec in data["Condition2"]]].reset_index(drop=True)
data = data[[rec != "RRAe" for rec in data["Condition2"]]].reset_index(drop=True)
data = data[[rec != "2.5Fin" for rec in data["HouseStyle"]]].reset_index(drop=True)
data = data[[rec != "Metal" for rec in data["RoofMatl"]]].reset_index(drop=True)
data = data[[rec != "Membran" for rec in data["RoofMatl"]]].reset_index(drop=True)
data = data[[rec != "Roll" for rec in data["RoofMatl"]]].reset_index(drop=True)
data = data[[rec != "ClyTile" for rec in data["RoofMatl"]]].reset_index(drop=True)

data = data[[rec != "Stone" for rec in data["Exterior1st"]]].reset_index(drop=True)
data = data[[rec != "ImStucc" for rec in data["Exterior1st"]]].reset_index(drop=True)
data = data[[rec != "Other" for rec in data["Exterior1st"]]].reset_index(drop=True)
data = data[[rec != "Other" for rec in data["Exterior2nd"]]].reset_index(drop=True)

data = data[[rec != "OthW" for rec in data["Heating"]]].reset_index(drop=True)
data = data[[rec != "Floor" for rec in data["Heating"]]].reset_index(drop=True)
data = data[[rec != "Mix" for rec in data["Electrical"]]].reset_index(drop=True)
data = data[[type(rec) != float for rec in data["Electrical"]]].reset_index(drop=True)

data = data[[rec != "Ex" for rec in data["GarageQual"]]].reset_index(drop=True)
data = data[[rec != "Fa" for rec in data["PoolQC"]]].reset_index(drop=True)

# %%
data_test = data_test[[type(rec) != float for rec in data_test['MSZoning']]]
data_test = data_test[[type(rec) != float for rec in data_test['Utilities']]]
data_test = data_test[[type(rec) != float for rec in data_test['Exterior1st']]]
data_test = data_test[[type(rec) != float for rec in data_test['KitchenQual']]]
data_test = data_test[[type(rec) != float for rec in data_test['Functional']]]
data_test = data_test[[type(rec) != float for rec in data_test['SaleType']]]

data_test = data_test[[rec != 'Ex' for rec in data_test['GarageCond']]]

# %% [markdown]
# # Preprocess data

# %% [markdown]
# ### Define a pipeline for processing data

# %%
def preprocess_data(df_data: pd.DataFrame, preproc_obj=None):
    df_data = df_data.copy(deep=True)

    train_preprocessors = preproc_obj is None

    # Encoding Categorical Features
    if train_preprocessors:
        preproc_obj = dict()
        preproc_obj["ss"] = dict()
        preproc_obj["le"] = dict()
        preproc_obj["mms"] = dict()

    for col_name_ in df_data.columns:
        df_data[col_name_] = df_data[col_name_].fillna(0).tolist()

    for key_ in data.keys():
        if data[key_].dtypes == "object":
            if train_preprocessors:
                preproc_obj["le"][key_] = LabelEncoder()
                preproc_obj["le"][key_].fit(df_data[key_].to_list())
            try:
                df_data[key_] = preproc_obj["le"][key_].transform(df_data[key_].to_list())
            except Exception as eeee:
                print(key_)
                raise eeee
        else:
            df_data[key_] = df_data[key_]

    if train_preprocessors:
        df_data.drop(df_data.index[-1], inplace=True)

    # Take log of the Target output
    df_data["SalePrice"] = np.log(df_data["SalePrice"])

    list_keep_data = ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
                      'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'RoofStyle',
                      'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
                      'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'Heating', 'HeatingQC', 'CentralAir',
                      'Electrical', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
                      'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu',
                      'GarageType', 'GarageFinish', 'GarageCars', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolArea',
                      'PoolQC', 'Fence', 'MiscFeature', 'MoSold', 'SaleType', 'SaleCondition', ]
    list_ss_data = ['MSSubClass', 'LotFrontage', 'Neighborhood', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
                    'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '2ndFlrSF', 'LowQualFinSF',
                    'GarageYrBlt', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
                    'ScreenPorch', 'MiscVal', 'YrSold', ]
    list_log_data = ['LotArea', '1stFlrSF', 'GrLivArea', ]

    for col_name_ in list_log_data:
        df_data[col_name_] = np.log(df_data[col_name_])

    for col_name_ in list_ss_data:
        if train_preprocessors:
            preproc_obj["ss"][col_name_] = StandardScaler()
            preproc_obj["ss"][col_name_].fit(np.array(df_data[col_name_]).reshape(-1, 1))
        df_data[col_name_] = preproc_obj["ss"][col_name_].transform(np.array(df_data[col_name_]).reshape(-1, 1))

    for col_name_ in df_data.columns:
        if col_name_ == 'SalePrice':
            continue
        if train_preprocessors:
            preproc_obj["mms"][col_name_] = MinMaxScaler(feature_range=(-1, 1))
            try:
                preproc_obj["mms"][col_name_].fit(np.array(df_data[col_name_]).reshape(-1, 1))
            except Exception as eee:
                print(col_name_)
                raise eee
        df_data[col_name_] = preproc_obj["mms"][col_name_].transform(np.array(df_data[col_name_]).reshape(-1, 1))

    return df_data, preproc_obj

# %%
data_num_train, preprocessing_obj = preprocess_data(data)

# %%
data_num_test, _ = preprocess_data(data_test, preprocessing_obj)

# %%
rcParams['figure.figsize'] = 10, 12


def draw_pred_lines(y_pred, y_real):
    drawing_df = pd.DataFrame({"Pred": y_pred, "Real": y_real})
    drawing_df = drawing_df.sort_values("Real").reset_index(drop=True)

    for key_, val_ in drawing_df.items():
        plt.plot(range(len(val_)), val_, label=key_)

    plt.xlabel("No")
    plt.ylabel("Step Time")
    plt.title("Pred vs Real Step Time")
    plt.legend()
    plt.show()


def draw_few_lines(lines_dict: dict, range_draw=None, x_label="x", y_label="y", title="f(x)"):
    for key_, val_ in lines_dict.items():
        plt.plot(range(len(val_)) if not range_draw else range_draw, val_, label=key_)

    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.legend()
    plt.show()

# %% [markdown]
# # 1. Tune Linear Regression model

# %%
linear_regressor = LinearRegression(fit_intercept=False)
linear_regressor.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

train_pred = linear_regressor.predict(data_num_train.drop('SalePrice', axis=1))
rmse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)
print(rmse_train)

draw_pred_lines(train_pred, data_num_train['SalePrice'].to_list())
# Out:
# 0.11629003404943705

# %%
test_pred = linear_regressor.predict(data_num_test.drop('SalePrice', axis=1))
rmse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)
print(rmse_test)

draw_pred_lines(test_pred, data_num_test['SalePrice'].to_list())
# Out:
# 0.37717219464742296

# %% [markdown]
# # 2. Decision Tree model

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
dt_model = DecisionTreeRegressor(min_samples_leaf=800)
dt_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

train_pred = dt_model.predict(data_num_train.drop('SalePrice', axis=1))
mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)
r2_score_train = r2_score(data_num_train['SalePrice'], train_pred)
print(f"MSE={mse_train}, R2_score={r2_score_train}")

draw_pred_lines(train_pred, data_num_train['SalePrice'].to_list())
# Out:
# MSE=0.3983265223184813, R2_score=0.0

# %%
test_pred = dt_model.predict(data_num_test.drop('SalePrice', axis=1))
mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)
r2_score_test = r2_score(data_num_test['SalePrice'], test_pred)
print("On test data:")
print(f"MSE={mse_test}, R2_score={r2_score_test}")

draw_pred_lines(test_pred, data_num_test['SalePrice'].to_list())
# Out:
# On test data:
# MSE=0.11152577563241893, R2_score=-0.5660151762769154

# %%
mse_train_list = []
mse_test_list = []

for min_samples_leaf in range(1, 1000):
    dt_model = DecisionTreeRegressor(min_samples_leaf=min_samples_leaf)
    dt_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

    train_pred = dt_model.predict(data_num_train.drop('SalePrice', axis=1))
    mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)

    test_pred = dt_model.predict(data_num_test.drop('SalePrice', axis=1))
    mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)

    mse_train_list.append(mse_train)
    mse_test_list.append(mse_test)

draw_few_lines({"mse_train": mse_train_list, "mse_test": mse_test_list},
               range_draw=list(range(1, 1000)),
               x_label="min_sample_leaf", y_label="MSE", title="MSE Vs Min Sample Leaf")

# %%
mse_train_list = []
mse_test_list = []

for max_leaf_nodes in range(2, 1450):
    dt_model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes)
    dt_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

    train_pred = dt_model.predict(data_num_train.drop('SalePrice', axis=1))
    mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)

    test_pred = dt_model.predict(data_num_test.drop('SalePrice', axis=1))
    mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)

    mse_train_list.append(mse_train)
    mse_test_list.append(mse_test)

draw_few_lines({"mse_train": mse_train_list, "mse_test": mse_test_list},
               range_draw=list(range(2, 1450)),
               x_label="max_leaf_nodes", y_label="MSE", title="MSE Vs max_leaf_nodes")

# %%
mse_train_list = []
mse_test_list = []

for max_depth in range(1, 1450):
    dt_model = DecisionTreeRegressor(max_depth=max_depth)
    dt_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

    train_pred = dt_model.predict(data_num_train.drop('SalePrice', axis=1))
    mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)

    test_pred = dt_model.predict(data_num_test.drop('SalePrice', axis=1))
    mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)

    mse_train_list.append(mse_train)
    mse_test_list.append(mse_test)

draw_few_lines({"mse_train": mse_train_list, "mse_test": mse_test_list},
               range_draw=list(range(1, 1450)),
               x_label="max_depth", y_label="MSE", title="MSE Vs max_depth")

# %% [markdown]
# # 3. Random Forest model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor()
rf_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

train_pred = rf_model.predict(data_num_train.drop('SalePrice', axis=1))
mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)
r2_score_train = r2_score(data_num_train['SalePrice'], train_pred)
print(f"MSE={mse_train}, R2_score={r2_score_train}")

draw_pred_lines(train_pred, data_num_train['SalePrice'].to_list())
# Out:
# MSE=0.05382069123416009, R2_score=0.9817433918890001

# %%
test_pred = rf_model.predict(data_num_test.drop('SalePrice', axis=1))
mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)
r2_score_test = r2_score(data_num_test['SalePrice'], test_pred)
print("On test data:")
print(f"MSE={mse_test}, R2_score={r2_score_test}")

draw_pred_lines(test_pred, data_num_test['SalePrice'].to_list())
# Out:
# On test data:
# MSE=0.3638443713890899, R2_score=-15.667742542785852

# %%
mse_train_list = []
mse_test_list = []

for n_estimators in range(1, 100):
    rf_model = RandomForestRegressor(n_estimators=n_estimators)
    rf_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

    train_pred = rf_model.predict(data_num_train.drop('SalePrice', axis=1))
    mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)

    test_pred = rf_model.predict(data_num_test.drop('SalePrice', axis=1))
    mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)

    mse_train_list.append(mse_train)
    mse_test_list.append(mse_test)

draw_few_lines({"mse_train": mse_train_list, "mse_test": mse_test_list},
               range_draw=list(range(1, 100)),
               x_label="max_depth", y_label="MSE", title="MSE Vs max_depth")

# %% [markdown]
# # 4. Gradient Boosting Regression

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr_model = GradientBoostingRegressor(n_estimators=50, learning_rate=0.1, random_state=0)

gbr_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

train_pred = gbr_model.predict(data_num_train.drop('SalePrice', axis=1))
mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)
r2_score_train = r2_score(data_num_train['SalePrice'], train_pred)
print(f"MSE={mse_train}, R2_score={r2_score_train}")

draw_pred_lines(train_pred, data_num_train['SalePrice'].to_list())
# Out:
# MSE=0.10143394238295658, R2_score=0.935153257983447

# %%
test_pred = gbr_model.predict(data_num_test.drop('SalePrice', axis=1))
mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)
r2_score_test = r2_score(data_num_test['SalePrice'], test_pred)
print("On test data:")
print(f"MSE={mse_test}, R2_score={r2_score_test}")

draw_pred_lines(test_pred, data_num_test['SalePrice'].to_list())
# Out:
# On test data:
# MSE=0.36434616926753305, R2_score=-15.713749055570041

# %% [markdown]
# # 7. Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha=1_875.1)

ridge_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

train_pred = ridge_model.predict(data_num_train.drop('SalePrice', axis=1))
mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)
r2_score_train = r2_score(data_num_train['SalePrice'], train_pred)
print(f"MSE={mse_train}, R2_score={r2_score_train}")

draw_pred_lines(train_pred, data_num_train['SalePrice'].to_list())
# Out:
# MSE=0.22468017228977658, R2_score=0.6818359932211079

# %%
test_pred = ridge_model.predict(data_num_test.drop('SalePrice', axis=1))
mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)
r2_score_test = r2_score(data_num_test['SalePrice'], test_pred)
print("On test data:")
print(f"MSE={mse_test}, R2_score={r2_score_test}")

draw_pred_lines(test_pred, data_num_test['SalePrice'].to_list())
# Out:
# On test data:
# MSE=0.23109689289008647, R2_score=-5.724092429880332

# %%
mse_train_list = []
mse_test_list = []

for alpha in [0.1 + x * 0.1 for x in range(0, 2000)]:
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

    train_pred = ridge_model.predict(data_num_train.drop('SalePrice', axis=1))
    mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)

    test_pred = ridge_model.predict(data_num_test.drop('SalePrice', axis=1))
    mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)

    mse_train_list.append(mse_train)
    mse_test_list.append(mse_test)

draw_few_lines({"mse_train": mse_train_list, "mse_test": mse_test_list},
               range_draw=[0.1 + x * 0.1 for x in range(0, 2000)],
               x_label="max_depth", y_label="MSE", title="MSE Vs max_depth")

# %%
mse_train_list = []
mse_test_list = []

for alpha in [0.1 + x * 0.1 for x in range(2000, 4000)]:
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

    train_pred = ridge_model.predict(data_num_train.drop('SalePrice', axis=1))
    mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)

    test_pred = ridge_model.predict(data_num_test.drop('SalePrice', axis=1))
    mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)

    mse_train_list.append(mse_train)
    mse_test_list.append(mse_test)

draw_few_lines({"mse_train": mse_train_list, "mse_test": mse_test_list},
               range_draw=[0.1 + x * 0.1 for x in range(2000, 4000)],
               x_label="max_depth", y_label="MSE", title="MSE Vs max_depth")

# %%
mse_train_list = []
mse_test_list = []

for alpha in [0.1 + x * 0.1 for x in range(4000, 6000)]:
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

    train_pred = ridge_model.predict(data_num_train.drop('SalePrice', axis=1))
    mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)

    test_pred = ridge_model.predict(data_num_test.drop('SalePrice', axis=1))
    mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)

    mse_train_list.append(mse_train)
    mse_test_list.append(mse_test)

draw_few_lines({"mse_train": mse_train_list, "mse_test": mse_test_list},
               range_draw=[0.1 + x * 0.1 for x in range(4000, 6000)],
               x_label="max_depth", y_label="MSE", title="MSE Vs max_depth")

# %%
mse_train_list = []
mse_test_list = []

for alpha in [0.1 + x * 0.1 for x in range(6000, 8000)]:
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

    train_pred = ridge_model.predict(data_num_train.drop('SalePrice', axis=1))
    mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)

    test_pred = ridge_model.predict(data_num_test.drop('SalePrice', axis=1))
    mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)

    mse_train_list.append(mse_train)
    mse_test_list.append(mse_test)

draw_few_lines({"mse_train": mse_train_list, "mse_test": mse_test_list},
               range_draw=[0.1 + x * 0.1 for x in range(6000, 8000)],
               x_label="max_depth", y_label="MSE", title="MSE Vs max_depth")

# %%
mse_train_list = []
mse_test_list = []

for alpha in [0.1 + x * 0.1 for x in range(8000, 12000)]:
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

    train_pred = ridge_model.predict(data_num_train.drop('SalePrice', axis=1))
    mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)

    test_pred = ridge_model.predict(data_num_test.drop('SalePrice', axis=1))
    mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)

    mse_train_list.append(mse_train)
    mse_test_list.append(mse_test)

draw_few_lines({"mse_train": mse_train_list, "mse_test": mse_test_list},
               range_draw=[0.1 + x * 0.1 for x in range(8000, 12000)],
               x_label="max_depth", y_label="MSE", title="MSE Vs max_depth")

# %%
mse_train_list = []
mse_test_list = []

for alpha in [0.1 + x * 0.1 for x in range(12000, 16000)]:
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

    train_pred = ridge_model.predict(data_num_train.drop('SalePrice', axis=1))
    mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)

    test_pred = ridge_model.predict(data_num_test.drop('SalePrice', axis=1))
    mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)

    mse_train_list.append(mse_train)
    mse_test_list.append(mse_test)

draw_few_lines({"mse_train": mse_train_list, "mse_test": mse_test_list},
               range_draw=[0.1 + x * 0.1 for x in range(12000, 16000)],
               x_label="max_depth", y_label="MSE", title="MSE Vs max_depth")

# %%
mse_train_list = []
mse_test_list = []

for alpha in [0.1 + x * 0.1 for x in range(16_000, 20_000)]:
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

    train_pred = ridge_model.predict(data_num_train.drop('SalePrice', axis=1))
    mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)

    test_pred = ridge_model.predict(data_num_test.drop('SalePrice', axis=1))
    mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)

    mse_train_list.append(mse_train)
    mse_test_list.append(mse_test)

draw_few_lines({"mse_train": mse_train_list, "mse_test": mse_test_list},
               range_draw=[0.1 + x * 0.1 for x in range(16_000, 20_000)],
               x_label="max_depth", y_label="MSE", title="MSE Vs max_depth")

# %% [markdown]
# # 8. Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
lasso_model = Lasso(alpha=1.0)

lasso_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

train_pred = lasso_model.predict(data_num_train.drop('SalePrice', axis=1))
mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)
r2_score_train = r2_score(data_num_train['SalePrice'], train_pred)
print(f"MSE={mse_train}, R2_score={r2_score_train}")

draw_pred_lines(train_pred, data_num_train['SalePrice'].to_list())
# Out:
# MSE=0.3983265223184813, R2_score=0.0

# %%
test_pred = lasso_model.predict(data_num_test.drop('SalePrice', axis=1))
mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)
r2_score_test = r2_score(data_num_test['SalePrice'], test_pred)
print("On test data:")
print(f"MSE={mse_test}, R2_score={r2_score_test}")

draw_pred_lines(test_pred, data_num_test['SalePrice'].to_list())
# Out:
# On test data:
# MSE=0.11152577563241572, R2_score=-0.5660151762768253

# %%
mse_train_list = []
mse_test_list = []

for alpha in [0.1 + x * 0.1 for x in range(0, 2000)]:
    lasso_model = Ridge(alpha=alpha)
    lasso_model.fit(data_num_train.drop('SalePrice', axis=1), data_num_train['SalePrice'])

    train_pred = lasso_model.predict(data_num_train.drop('SalePrice', axis=1))
    mse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, squared=False)

    test_pred = lasso_model.predict(data_num_test.drop('SalePrice', axis=1))
    mse_test = mean_squared_error(data_num_test['SalePrice'], test_pred, squared=False)

    mse_train_list.append(mse_train)
    mse_test_list.append(mse_test)

draw_few_lines({"mse_train": mse_train_list, "mse_test": mse_test_list},
               range_draw=[0.1 + x * 0.1 for x in range(0, 2000)],
               x_label="max_depth", y_label="MSE", title="MSE Vs max_depth")

# %% [markdown]
# # ANN Regression

# %%
from keras import models
from keras import layers

# %%
model = models.Sequential()

model.add(layers.Dense(units=256, input_shape=(None, len(data_num_train.columns) - 1), activation='relu'))
model.add(layers.Dropout(rate=0.5))
model.add(layers.Dense(units=256, activation='relu'))
model.add(layers.Dropout(rate=0.5))
model.add(layers.Dense(units=256, activation='relu'))
model.add(layers.Dropout(rate=0.5))
model.add(layers.Dense(units=256, activation='relu'))
model.add(layers.Dropout(rate=0.5))
model.add(layers.Dense(units=256, activation='relu'))
model.add(layers.Dropout(rate=0.5))
model.add(layers.Dense(units=1))

model.compile(optimizer="adam", loss="mean_squared_error")
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, None, 256)         20480
#
#  dropout_11 (Dropout)        (None, None, 256)         0
#
#  dense_16 (Dense)            (None, None, 256)         65792
#
#  dropout_12 (Dropout)        (None, None, 256)         0
#
#  dense_17 (Dense)            (None, None, 256)         65792
#
#  dropout_13 (Dropout)        (None, None, 256)         0
#
#  dense_18 (Dense)            (None, None, 256)         65792
#
#  dropout_14 (Dropout)        (None, None, 256)         0
#
#  dense_19 (Dense)            (None, None, 256)         65792
#
#  dropout_15 (Dropout)        (None, None, 256)         0
#
#  dense_20 (Dense)            (None, None, 1)           257
#
# =================================================================
# Total params: 283905 (1.08 MB)
# Trainable params: 283905 (1.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 1500
history = model.fit(x=data_num_train.drop("SalePrice", axis=1), y=data_num_train["SalePrice"], epochs=epochs)
# Out:
# Epoch 1/1500
# 45/45 [==============================] - 2s 5ms/step - loss: 29.9469
# Epoch 2/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 8.8271
# Epoch 3/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 7.8791
# Epoch 4/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 7.5650
# Epoch 5/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 6.6665
# Epoch 6/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 6.0342
# Epoch 7/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 5.7221
# Epoch 8/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 5.2162
# Epoch 9/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 5.3480
# Epoch 10/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 5.2013
# Epoch 11/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 4.8396
# Epoch 12/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 4.4077
# Epoch 13/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 4.4278
# Epoch 14/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 3.9651
# Epoch 15/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 3.5311
# Epoch 16/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 3.0909
# Epoch 17/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 3.0072
# Epoch 18/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 2.7073
# Epoch 19/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 2.3664
# Epoch 20/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 2.2718
# Epoch 21/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 1.9749
# Epoch 22/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 1.8630
# Epoch 23/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 1.7604
# Epoch 24/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 1.7654
# Epoch 25/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 1.7026
# Epoch 26/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 1.7549
# Epoch 27/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 1.6122
# Epoch 28/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 1.6314
# Epoch 29/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 1.5154
# Epoch 30/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 1.5366
# Epoch 31/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 1.
1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0212
# Epoch 1401/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0223
# Epoch 1402/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0213
# Epoch 1403/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0229
# Epoch 1404/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0215
# Epoch 1405/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0222
# Epoch 1406/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0226
# Epoch 1407/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0237
# Epoch 1408/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0227
# Epoch 1409/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0206
# Epoch 1410/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0206
# Epoch 1411/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0214
# Epoch 1412/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0249
# Epoch 1413/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0242
# Epoch 1414/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0246
# Epoch 1415/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0238
# Epoch 1416/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0253
# Epoch 1417/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0244
# Epoch 1418/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0214
# Epoch 1419/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0235
# Epoch 1420/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0205
# Epoch 1421/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0249
# Epoch 1422/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0258
# Epoch 1423/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0250
# Epoch 1424/1500
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0223
# Epoch 1425/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0233
# Epoch 1426/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0227
# Epoch 1427/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0252
# Epoch 1428/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0231
# Epoch 1429/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0228
# Epoch 1430/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0223
# Epoch 1431/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0247
# Epoch 1432/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0229
# Epoch 1433/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0227
# Epoch 1434/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0215
# Epoch 1435/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0242
# Epoch 1436/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0208
# Epoch 1437/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0210
# Epoch 1438/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0205
# Epoch 1439/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0229
# Epoch 1440/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0204
# Epoch 1441/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0213
# Epoch 1442/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0218
# Epoch 1443/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0208
# Epoch 1444/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0220
# Epoch 1445/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0236
# Epoch 1446/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0228
# Epoch 1447/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0203
# Epoch 1448/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0248
# Epoch 1449/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0240
# Epoch 1450/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0232
# Epoch 1451/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0224
# Epoch 1452/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0228
# Epoch 1453/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0239
# Epoch 1454/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0226
# Epoch 1455/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0237
# Epoch 1456/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0222
# Epoch 1457/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0229
# Epoch 1458/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0242
# Epoch 1459/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0225
# Epoch 1460/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0221
# Epoch 1461/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0230
# Epoch 1462/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0262
# Epoch 1463/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0224
# Epoch 1464/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0226
# Epoch 1465/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0221
# Epoch 1466/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0240
# Epoch 1467/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0215
# Epoch 1468/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0241
# Epoch 1469/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0220
# Epoch 1470/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0224
# Epoch 1471/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0240
# Epoch 1472/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0247
# Epoch 1473/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0245
# Epoch 1474/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0239
# Epoch 1475/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0235
# Epoch 1476/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0231
# Epoch 1477/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0249
# Epoch 1478/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0207
# Epoch 1479/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0204
# Epoch 1480/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0214
# Epoch 1481/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0224
# Epoch 1482/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0224
# Epoch 1483/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0220
# Epoch 1484/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0228
# Epoch 1485/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0204
# Epoch 1486/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0234
# Epoch 1487/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0219
# Epoch 1488/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0253
# Epoch 1489/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0226
# Epoch 1490/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0230
# Epoch 1491/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0222
# Epoch 1492/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0233
# Epoch 1493/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0212
# Epoch 1494/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0208
# Epoch 1495/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0206
# Epoch 1496/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0221
# Epoch 1497/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0204
# Epoch 1498/1500
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0223
# Epoch 1499/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0236
# Epoch 1500/1500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0214

# %%
import ctypes

def get_object_by_memory_address(address):
    return ctypes.cast(address, ctypes.py_object).value


history = get_object_by_memory_address(0x1843dcb80d0)

# %%
plt.plot(range(1, epochs + 1), history.history['loss'])

# %%
train_pred = model.predict(data_num_train.drop('SalePrice', axis=1), verbose=0)
rmse_train = mean_squared_error(data_num_train['SalePrice'], train_pred, )
print(rmse_train)

draw_pred_lines(list(train_pred), data_num_train['SalePrice'].to_list())
# Out:
# 0.0394907161864929

# %%
test_pred = model.predict(data_num_test.drop('SalePrice', axis=1), verbose=0)
rmse_test = mean_squared_error(data_num_test['SalePrice'], test_pred,)
print(rmse_test)

draw_pred_lines(list(test_pred), data_num_test['SalePrice'].to_list())
# Out:
# 0.05310703940641527
